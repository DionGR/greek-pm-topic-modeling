# %%
import pandas as pd
from bertopic import BERTopic
from sentence_transformers import SentenceTransformer
from nltk.tokenize import sent_tokenize
import itertools
from utils.data_loader import DataLoader

# %%
loader = DataLoader('../data/data_speeches.csv', '../data/data_statements.csv')
loader.process()

docs = loader.get_docs()
sentences = loader.get_sentences()

embeddings_gr = loader.load_embeddings("../data/embeddings/embeddings_gr.pkl")
embeddings_gr_media = loader.load_embeddings("../data/embeddings/embeddings_gr_media.pkl")
embeddings_gr_sentences = loader.load_embeddings("../data/embeddings/embeddings_gr_sentences.pkl")
embeddings_gr_media_sentences = loader.load_embeddings("../data/embeddings/embeddings_gr_media_sentences.pkl")

# %%
st_greek = SentenceTransformer('lighteternal/stsb-xlm-r-greek-transfer')
st_greek_media = SentenceTransformer('dimitriz/st-greek-media-bert-base-uncased')
# Out:
# 2024-04-04 16:02:01,509 | INFO | SentenceTransformer.py:107 | __init__ | Load pretrained SentenceTransformer: lighteternal/stsb-xlm-r-greek-transfer
# 2024-04-04 16:02:07,647 | INFO | SentenceTransformer.py:213 | __init__ | Use pytorch device_name: cpu
# 2024-04-04 16:02:07,647 | INFO | SentenceTransformer.py:107 | __init__ | Load pretrained SentenceTransformer: dimitriz/st-greek-media-bert-base-uncased
# 2024-04-04 16:02:10,168 | INFO | SentenceTransformer.py:213 | __init__ | Use pytorch device_name: cpu

# %%
print(f"Number of all docs: {len(docs)}")
print(f"Number of all sentences: {len(sentences)}")
# Out:
# Number of all docs: 2012
# Number of all sentences: 212471

# %%
from sklearn.feature_extraction.text import CountVectorizer
import advertools as adv

# %%
stopwords = adv.stopwords['greek']
stopwords = list(stopwords) +  ['χώρα', 'ελλάδα', 'κύριοι', 'κυρία', 'κυρίες', 'κύριο', 'συμπολίτες']
vectorizer_model = CountVectorizer(stop_words=stopwords, min_df=2, ngram_range=(1, 2))

# %%
topic_model = BERTopic(embedding_model=st_greek_media, vectorizer_model=vectorizer_model)
topics, _ = topic_model.fit_transform(docs, embeddings_gr_media)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1    725                                   -1_the_and_of_to
# 1       0    245                       0_κι_σήμερα_χρόνια_κυβέρνηση
# 2       1    113             1_υγείας_σήμερα_σύστημα_σύστημα υγείας
# 3       2     62                2_ευρωπαϊκής_ευρωπαϊκή_χώρες_ένωσης
# 4       3     61     3_προστασίας_πολιτικής προστασίας_θέλω_κάνουμε
# 5       4     55                      4_ευρώ_αγρότες_τομέα_προϊόντα
# 6       5     53                        5_τουρκία_χώρες_ροές_ασύλου
# 7       6     50                      6_ευρώπη_σήμερα_βίας_γυναίκες
# 8       7     49                                    7_the_and_to_of
# 9       8     45                   8_ευρώπη_γερμανία_πιστεύω_ζήτημα
# 10      9     41             9_οικονομία_ανάπτυξη_χρόνια_επενδύσεις
# 11     10     37                 10_επιχειρήσεις_υπάρχουν_χρόνια_κι
# 12     11     33                        11_τεστ_υγείας_μέτρα_σήμερα
# 13     12     30                                   12_the_we_and_in
# 14     13     30                13_εκκλησίας_θεόφιλος_τάφου_ελλάδος
# 15     14     25                 14_υγείας_εμβόλια_πανδημία_ψυχικής
# 16     15     25                  15_σήμερα_συντάξεις_εργασίας_ευρώ
# 17     16     22           16_τουρισμού_τουρισμό_τουρισμός_εργασίας
# 18     17     22                      17_δύο_σχέσεων_σχέσεις_μεγάλη
# 19     18     21         18_ενέργειας_αερίου_φυσικού αερίου_φυσικού
# 20     19     21             19_σχολείο_μαθητές_παιδιά_πρωθυπουργός
# 21     20     20                          20_έργο_έργα_δρόμος_έργου
# 22     21     20         21_αερίου_φυσικού αερίου_φυσικού_ενέργειας
# 23     22     20           22_μουσείο_πολιτισμού_ακρόπολης_μουσείου
# 24     23     19                                   23_and_we_the_to
# 25     24     17         24_εαβ_αεροπορίας_ενόπλων_ενόπλων δυνάμεων
# 26     25     17    25_λιμενικού_ναυτιλία_λιμενικού σώματος_σώματος
# 27     26     16                       26_περιφέρεια_ευρώ_έργα_εκατ
# 28     27     16                        27_γαλλίας_γαλλία_ευρώπη_de
# 29     28     16                 28_παιδιά_παιδί_διότι_πανεπιστήμιο
# 30     29     16                 29_ευχαριστώ_καναδά_erasmus_σήμερα
# 31     30     13                   30_ευρώπη_πολιτική_σήμερα_αλέξης
# 32     31     13                        31_θέλουν_κι_αστάθεια_κρίση
# 33     32     12          32_μουσείο_πολιτισμού_σήμερα_αρχαιολογικό
# 34     33     12  33_καραμανλής_καραμανλή_κι_κωνσταντίνος καραμα...
# 35     34     10                    34_μετρό_έργο_έργα_θεσσαλονίκης
# 36     35     10               35_φιντέλ_αγώνα_αγώνες_αντετοκούνμπο
#
#                                        Representation  \
# 0   [the, and, of, to, σήμερα, ευρώπη, χρόνια, in,...
# 1   [κι, σήμερα, χρόνια, κυβέρνηση, χώρας, νέα, δι...
# 2   [υγείας, σήμερα, σύστημα, σύστημα υγείας, νοσο...
# 3   [ευρωπαϊκής, ευρωπαϊκή, χώρες, ένωσης, σήμερα,...
# 4   [προστασίας, πολιτικής προστασίας, θέλω, κάνου...
# 5   [ευρώ, αγρότες, τομέα, προϊόντα, θέλω, σήμερα,...
# 6   [τουρκία, χώρες, ροές, ασύλου, σύνορα, ευρωπαϊ...
# 7   [ευρώπη, σήμερα, βίας, γυναίκες, γυναικών, χώρ...
# 8       [the, and, to, of, is, in, we, that, it, for]
# 9   [ευρώπη, γερμανία, πιστεύω, ζήτημα, θέλω, σήμε...
# 10  [οικονομία, ανάπτυξη, χρόνια, επενδύσεις, οικο...
# 11  [επιχειρήσεις, υπάρχουν, χρόνια, κι, υπάρχει, ...
# 12  [τεστ, υγείας, μέτρα, σήμερα, κυβέρνηση, κρουσ...
# 13  [the, we, and, in, to, of, σαμαράς, is, αντώνη...
# 14  [εκκλησίας, θεόφιλος, τάφου, ελλάδος, πατριάρχ...
# 15  [υγείας, εμβόλια, πανδημία, ψυχικής, ψυχικής υ...
# 16  [σήμερα, συντάξεις, εργασίας, ευρώ, πολίτες, υ...
# 17  [τουρισμού, τουρισμό, τουρισμός, εργασίας, του...
# 18  [δύο, σχέσεων, σχέσεις, μεγάλη, ευρωπαϊκή, ευκ...
# 19  [ενέργειας, αερίου, φυσικού αερίου, φυσικού, α...
# 20  [σχολείο, μαθητές, παιδιά, πρωθυπουργός, εκπαί...
# 21  [έργο, έργα, δρόμος, έργου, σήμερα, τμήμα, υπο...
# 22  [αερίου, φυσικού αερίου, φυσικού, ενέργειας, έ...
# 23  [μουσείο, πολιτισμού, ακρόπολης, μουσείου, οακ...
# 24    [and, we, the, to, our, of, is, in, that, νατο]
# 25  [εαβ, αεροπορίας, ενόπλων, ενόπλων δυνάμεων, ά...
# 26  [λιμενικού, ναυτιλία, λιμενικού σώματος, σώματ...
# 27  [περιφέρεια, ευρώ, έργα, εκατ, τομέα, πρόγραμμ...
# 28  [γαλλίας, γαλλία, ευρώπη, de, la, σχέση, ευρώπ...
# 29  [παιδιά, παιδί, διότι, πανεπιστήμιο, σήμερα, π...
# 30  [ευχαριστώ, καναδά, erasmus, σήμερα, δύο, just...
# 31  [ευρώπη, πολιτική, σήμερα, αλέξης, υπάρχει, ευ...
# 32  [θέλουν, κι, αστάθεια, κρίση, μπροστά, χάος, π...
# 33  [μουσείο, πολιτισμού, σήμερα, αρχαιολογικό, αι...
# 34  [καραμανλής, καραμανλή, κι, κωνσταντίνος καραμ...
# 35  [μετρό, έργο, έργα, θεσσαλονίκης, πειραιά, θεσ...
# 36  [φιντέλ, αγώνα, αγώνες, αντετοκούνμπο, ιστορία...
#
#                                   Representative_Docs
# 0   [«Στόχος μας σε ένα χρόνο από τώρα η χώρα να β...
# 1   [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Πέμπτη 30 Ιανουαρί...
# 2   [Φίλες και φίλοι είναι η δεύτερη φορά που επισ...
# 3   [Κύριοι Πρόεδροι κυρίες και κύριοι Ολοκληρώσαμ...
# 4   [Δεν νομίζω ότι χρειάστηκε κα Κωνσταντοπούλου ...
# 5   [Γεια σας! Σας ευχαριστώ θερμά γι αυτή την υπο...
# 6   [Οι κοινές δηλώσεις του Πρωθυπουργού Κυριάκου ...
# 7   [Κυρίες και κύριοι Είναι πολύ σημαντικό ότι η ...
# 8   [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Τετάρτη 2 Οκτωβρίο...
# 9   [Κυριάκος Μητσοτάκης: Αγαπητέ Καγκελάριε της Ο...
# 10  [Νίκος Μπακατσέλος: Κύριε Πρόεδρε καλώς ήρθατε...
# 11  [Μήνυμα στον επιχειρηματικό κόσμο της χώρας να...
# 12  [Επιτρέψτε μου να ξεκινήσω με αυτά τα οποία άκ...
# 13  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Τρίτη 9 Οκτωβρίου ...
# 14  [Κοινό ανακοινωθέν Πολιτείας – Εκκλησίας Θέλω ...
# 15  [Ο Πρωθυπουργός Κυριάκος Μητσοτάκης συναντήθηκ...
# 16  [Ομιλία στη Βουλή των Ελλήνων για τη διανομή Κ...
# 17  [Ο Πρωθυπουργός Κυριάκος Μητσοτάκης παρέστη κα...
# 18  [Αξιότιμοι κύριοι Πρωθυπουργοί Εκλεκτοί προσκε...
# 19  [Κυρίες και κύριοι. Με χαρά σας καλωσορίζω στη...
# 20  [Τη διαδικτυακή διδασκαλία του μαθήματος Ιστορ...
# 21  [Γεια σας φίλες και φίλοι. Είναι σήμερα μια ημ...
# 22  [«Από σήμερα η Ξάνθη ολόκληρη η Περιφέρεια Ανα...
# 23  [«Δεν έχω καμία αμφιβολία ότι το νέο ΟΑΚΑ το “...
# 24  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Παρασκευή 21 Φεβρο...
# 25  [Ομιλία στην εκδήλωση της Πολεμικής Αεροπορίας...
# 26  [Ravi Agrawal: Έχω τη χαρά σήμερα να συζητώ με...
# 27  [Ομιλία στο 11o Περιφερειακό Συνέδριο για την ...
# 28  [«Η σχέση Ελλάδας – Γαλλίας είναι ξεχωριστή. Ε...
# 29  [Ομιλία στη Βουλή για το δημογραφικό πρόβλημα....
# 30  [Ο Πρωθυπουργός Κυριάκος Μητσοτάκης έλαβε μέρο...
# 31  [Συντρόφισσες και Σύντροφοι είναι μια Κοινοβου...
# 32  [Κυρίες και Κύριοι Υπουργοί Θέλω να σας συγχαρ...
# 33  [Ο Πρωθυπουργός Κυριάκος Μητσοτάκης παρέστη κα...
# 34  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Παρασκευή 15 Νοεμβ...
# 35  [«Στη λεωφόρο της ανάπτυξης πρέπει να έχουν θέ...
# 36  [Ο Πρωθυπουργός Κυριάκος Μητσοτάκης μίλησε το ...

# %%
topic_model = BERTopic(embedding_model=st_greek, vectorizer_model=vectorizer_model)
topics, _ = topic_model.fit_transform(docs, embeddings_gr)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                               Name  \
# 0      -1    634                                   -1_the_and_of_to
# 1       0    166        0_υγείας_εμβολιασμού_σύστημα υγείας_σύστημα
# 2       1    121                           1_τσίπρα_κι_σήμερα_κύριε
# 3       2     75                  2_χώρες_ευρώπη_ευρωπαϊκή_πρόβλημα
# 4       3     74                         3_κι_χρόνια_δημοκρατία_νέα
# 5       4     67          4_ενέργειας_αερίου_φυσικού αερίου_φυσικού
# 6       5     66  5_προστασίας_πολιτικής προστασίας_φωτιά_πολιτικής
# 7       6     61            6_συλλυπητήρια_υπήρξε_εκφράζω_υπηρέτησε
# 8       7     51              7_σχολείο_παιδιά_αναπηρία_εκπαίδευσης
# 9       8     44                    8_ευρώπη_συμφωνία_ελληνική_μάχη
# 10      9     43                         9_έργο_έργα_μετρό_υποδομών
# 11     10     36  10_τεχνολογίας_τεχνολογία_καινοτομίας_επιχειρή...
# 12     11     34                 11_χρόνια_επιχειρήσεις_αύξηση_ευρώ
# 13     12     30     12_λιμενικού_σώματος_λιμενικού σώματος_ενόπλων
# 14     13     28                     13_καναδά_ευχαριστώ_χρόνια_δύο
# 15     14     27    14_κυπριακής_κυπριακής δημοκρατίας_κύπρο_κύπρος
# 16     15     27                              15_de_que_en_ρουμανία
# 17     16     25                           16_κι_χρόνια_χώρας_κρίση
# 18     17     25                  17_οοσα_κυριάκος_δύο_πρωθυπουργός
# 19     18     25  18_μητσοτάκης_επενδύσεις_πιστεύω_κυριάκος μητσ...
# 20     19     24                   19_βίας_γυναικών_γυναίκες_θύματα
# 21     20     24        20_μουσείο_πολιτισμού_μουσείου_αρχαιολογικό
# 22     21     23             21_πρωθυπουργός_αττική_μεγάλη_υπουργός
# 23     22     22             22_αερίου_φυσικού αερίου_φυσικού_αέριο
# 24     23     22                              23_ευρώπη_the_οαεδ_we
# 25     24     21                  24_κυβέρνηση_εργασίας_νέα_δημόσιο
# 26     25     21         25_τουρισμού_τουρισμό_τουρισμός_τουριστική
# 27     26     21                       26_τουρκίας_τουρκία_δύο_νατο
# 28     27     18                      27_περιφέρεια_έργα_ευρώ_αφορά
# 29     28     17                 28_έργα_περιφέρεια_υπουργός_σχέδιο
# 30     29     16                              29_κίνας_κίνα_the_and
# 31     30     16                        30_κι_συριζα_εκλογές_χρόνια
# 32     31     15                                 31_the_and_we_that
# 33     32     13  32_εκλογές_πρωθυπουργου_γραφειο τυπου_τυπου πρ...
# 34     33     12                    33_ευρώπη_ευρώπης_γαλλία_σήμερα
# 35     34     12                34_νατο_συμφωνία_μεσόγειο_αμυντικής
# 36     35     12                                 35_the_to_and_that
# 37     36     12                  36_πειραιά_ναυτιλία_κέντρο_λιμάνι
# 38     37     11     37_αντετοκούνμπο_μητέρα πατρίδα_γιάννη_πατρίδα
# 39     38     11                38_ισραήλ_χαμάς_παλαιστινιακό_αφορά
# 40     39     10                                 39_and_the_of_that
#
#                                        Representation  \
# 0       [the, and, of, to, in, is, we, for, our, are]
# 1   [υγείας, εμβολιασμού, σύστημα υγείας, σύστημα,...
# 2   [τσίπρα, κι, σήμερα, κύριε, διότι, κυβέρνηση, ...
# 3   [χώρες, ευρώπη, ευρωπαϊκή, πρόβλημα, πρόσφυγες...
# 4   [κι, χρόνια, δημοκρατία, νέα, σήμερα, έλληνες,...
# 5   [ενέργειας, αερίου, φυσικού αερίου, φυσικού, ε...
# 6   [προστασίας, πολιτικής προστασίας, φωτιά, πολι...
# 7   [συλλυπητήρια, υπήρξε, εκφράζω, υπηρέτησε, θλί...
# 8   [σχολείο, παιδιά, αναπηρία, εκπαίδευσης, εκπαί...
# 9   [ευρώπη, συμφωνία, ελληνική, μάχη, κυβέρνηση, ...
# 10  [έργο, έργα, μετρό, υποδομών, έργου, υπουργός,...
# 11  [τεχνολογίας, τεχνολογία, καινοτομίας, επιχειρ...
# 12  [χρόνια, επιχειρήσεις, αύξηση, ευρώ, οικονομία...
# 13  [λιμενικού, σώματος, λιμενικού σώματος, ενόπλω...
# 14  [καναδά, ευχαριστώ, χρόνια, δύο, σήμερα, μεγάλ...
# 15  [κυπριακής, κυπριακής δημοκρατίας, κύπρο, κύπρ...
# 16  [de, que, en, ρουμανία, ευρωπαϊκή, ευρωπαϊκή έ...
# 17  [κι, χρόνια, χώρας, κρίση, θέλουν, σήμερα, εκλ...
# 18  [οοσα, κυριάκος, δύο, πρωθυπουργός, μητσοτάκης...
# 19  [μητσοτάκης, επενδύσεις, πιστεύω, κυριάκος μητ...
# 20  [βίας, γυναικών, γυναίκες, θύματα, φύλων, γυνα...
# 21  [μουσείο, πολιτισμού, μουσείου, αρχαιολογικό, ...
# 22  [πρωθυπουργός, αττική, μεγάλη, υπουργός, τουρι...
# 23  [αερίου, φυσικού αερίου, φυσικού, αέριο, ταπ, ...
# 24  [ευρώπη, the, οαεδ, we, to, εργασίας, of, ευρώ...
# 25  [κυβέρνηση, εργασίας, νέα, δημόσιο, ελληνικού,...
# 26  [τουρισμού, τουρισμό, τουρισμός, τουριστική, χ...
# 27  [τουρκίας, τουρκία, δύο, νατο, ελλάδας, πρόεδρ...
# 28  [περιφέρεια, έργα, ευρώ, αφορά, τομέα, ανάπτυξ...
# 29  [έργα, περιφέρεια, υπουργός, σχέδιο, δυτική μα...
# 30  [κίνας, κίνα, the, and, to, of, we, in, is, μέρη]
# 31  [κι, συριζα, εκλογές, χρόνια, λένε, ανάπτυξη, ...
# 32  [the, and, we, that, to, as, of, to be, very, is]
# 33  [εκλογές, πρωθυπουργου, γραφειο τυπου, τυπου π...
# 34  [ευρώπη, ευρώπης, γαλλία, σήμερα, ευρωπαϊκής, ...
# 35  [νατο, συμφωνία, μεσόγειο, αμυντικής, συμμαχία...
# 36  [the, to, and, that, we, is, of, επενδύσεων, g...
# 37  [πειραιά, ναυτιλία, κέντρο, λιμάνι, philip mor...
# 38  [αντετοκούνμπο, μητέρα πατρίδα, γιάννη, πατρίδ...
# 39  [ισραήλ, χαμάς, παλαιστινιακό, αφορά, περιοχή,...
# 40  [and, the, of, that, to, in, nuclear, it, is, we]
#
#                                   Representative_Docs
# 0   [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Δευτέρα 16 Σεπτεμβ...
# 1   [Ο Πρωθυπουργός Κυριάκος Μητσοτάκης έλαβε μέρο...
# 2   [Ομιλία στη συζήτηση στη Βουλή του σχεδίου νόμ...
# 3   [Σας ευχαριστώ κυρία Γεννηματά για την ερώτηση...
# 4   [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Παρασκευή 11 Οκτωβ...
# 5   [«Αποτελεί υποχρέωσή μας όχι απλά εθνική όχι α...
# 6   [Ευχαριστώ κ. Πρόεδρε. Επιτρέψτε μου να ξεκινή...
# 7   [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Τετάρτη 6 Μαρτίου ...
# 8   [Κυρίες και κύριοι συνάδελφοι συνηθίζουμε να λ...
# 9   [Κυρίες και κύριοι συνάδελφοι Σήμερα μετά και ...
# 10  [Στα εγκαίνια της Παράκαμψης Αμφιλοχίας που ολ...
# 11  [Ο Πρωθυπουργός Κυριάκος Μητσοτάκης συμμετείχε...
# 12  [Κυρίες και κύριοι συνάδελφοι καθ’ όση ώρα άκο...
# 13  [Ομιλία του Πρωθυπουργού Αλέξη Τσίπρα στα στελ...
# 14  [Ο Πρωθυπουργός παρέστη και μίλησε σε ομογενει...
# 15  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Παρασκευή 7 Νοεμβρ...
# 16  [Δηλώσεις μετά την ολοκλήρωση της συνάντησης μ...
# 17  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Παρασκευή 23 Μαΐου...
# 18  [Ο Πρωθυπουργός Κυριάκος Μητσοτάκης συναντήθηκ...
# 19  [Κυριάκος Μητσοτάκης: Αγαπητέ Καγκελάριε της Ο...
# 20  [Ομιλία του Πρωθυπουργού Αλέξη Τσίπρα κατά την...
# 21  [Κυρίες και κύριοι είναι πραγματικά δύσκολο να...
# 22  [Τα τοπικά ζητήματα που απασχολούν τη Μαγνησία...
# 23  [«Ο νέος τερματικός σταθμός LNG αποτελεί μία ε...
# 24  [Μετά την ολοκλήρωση των εργασιών της σημερινή...
# 25  [Παναγιώτατε Κύριε υπουργέ κυρίες και κύριοι Τ...
# 26  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Τετάρτη 29 Μαΐου 2...
# 27  [Kυριάκος Μητσοτάκης: Είχα τη χαρά να υποδεχθώ...
# 28  [Η Ελλάδα μπορεί να σταθεί στα πόδια της και ν...
# 29  [O Πρωθυπουργός Κυριάκος Μητσοτάκης παρέστη κα...
# 30  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Παρασκευή 17 Μαΐου...
# 31  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Δευτέρα 12 Ιανουαρ...
# 32  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Τρίτη 17 Σεπτεμβρί...
# 33  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Κυριακή 21 Δεκεμβρ...
# 34  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Τρίτη 19 Φεβρουαρί...
# 35  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Παρασκευή 21 Φεβρο...
# 36  [Κύριε Αντιπρόεδρε της Ευρωπαϊκής Επιτροπής κύ...
# 37  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Παρασκευή 20 Ιουνί...
# 38  [ΓΡΑΦΕΙΟ ΤΥΠΟΥ ΠΡΩΘΥΠΟΥΡΓΟΥ Τρίτη 02 Ιουλίου 2...
# 39  [Γιάννης Καντέλης (ΣΚΑΪ): Και πάλι χθες είχαμε...
# 40  [Η Αυτού Υψηλότης Σεΐχης Mohammed Bin Zayed Al...

# %%
topic_model = BERTopic(embedding_model=st_greek, vectorizer_model=vectorizer_model)
topics, _ = topic_model.fit_transform(sentences, embeddings_gr_sentences)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[46], line 2
#       1 topic_model = BERTopic(embedding_model=st_greek, vectorizer_model=vectorizer_model)
# ----> 2 topics, _ = topic_model.fit_transform(sentences, embeddings_gr_sentences)
#
# File ~\.env\nlp-project\Lib\site-packages\bertopic\_bertopic.py:408, in BERTopic.fit_transform(self, documents, embeddings, images, y)
#     405         return self._combine_zeroshot_topics(documents, assigned_documents, assigned_embeddings)
#     407 # Reduce dimensionality
# --> 408 umap_embeddings = self._reduce_dimensionality(embeddings, y)
#     410 # Cluster reduced embeddings
#     411 documents, probabilities = self._cluster_embeddings(umap_embeddings, documents, y=y)
#
# File ~\.env\nlp-project\Lib\site-packages\bertopic\_bertopic.py:3355, in BERTopic._reduce_dimensionality(self, embeddings, y, partial_fit)
#    3352 try:
#    3353     # cuml umap needs y to be an numpy array
#    3354     y = np.array(y) if y is not None else None
# -> 3355     self.umap_model.fit(embeddings, y=y)
#    3356 except TypeError:
#    3358     self.umap_model.fit(embeddings)
#
# File ~\.env\nlp-project\Lib\site-packages\umap\umap_.py:2780, in UMAP.fit(self, X, y, force_all_finite)
#    2776 if self.transform_mode == "embedding":
#    2777     epochs = (
#    2778         self.n_epochs_list if self.n_epochs_list is not None else self.n_epochs
#    2779     )
# -> 2780     self.embedding_, aux_data = self._fit_embed_data(
#    2781         self._raw_data[index],
#    2782         epochs,
#    2783         init,
#    2784         random_state,  # JH why raw data?
#    2785     )
#    2787     if self.n_epochs_list is not None:
#    2788         if "embedding_list" not in aux_data:
#
# File ~\.env\nlp-project\Lib\site-packages\umap\umap_.py:2826, in UMAP._fit_embed_data(self, X, n_epochs, init, random_state)
#    2822 def _fit_embed_data(self, X, n_epochs, init, random_state):
#    2823     """A method wrapper for simplicial_set_embedding that can be
#    2824     replaced by subclasses.
#    2825     """
# -> 2826     return simplicial_set_embedding(
#    2827         X,
#    2828         self.graph_,
#    2829         self.n_components,
#    2830         self._initial_alpha,
#    2831         self._a,
#    2832         self._b,
#    2833         self.repulsion_strength,
#    2834         self.negative_sample_rate,
#    2835         n_epochs,
#    2836         init,
#    2837         random_state,
#    2838         self._input_distance_func,
#    2839         self._metric_kwds,
#    2840         self.densmap,
#    2841         self._densmap_kwds,
#    2842         self.output_dens,
#    2843         self._output_distance_func,
#    2844         self._output_metric_kwds,
#    2845         self.output_metric in ("euclidean", "l2"),
#    2846         self.random_state is None,
#    2847         self.verbose,
#    2848         tqdm_kwds=self.tqdm_kwds,
#    2849     )
#
# File ~\.env\nlp-project\Lib\site-packages\umap\umap_.py:1106, in simplicial_set_embedding(data, graph, n_components, initial_alpha, a, b, gamma, negative_sample_rate, n_epochs, init, random_state, metric, metric_kwds, densmap, densmap_kwds, output_dens, output_metric, output_metric_kwds, euclidean_output, parallel, verbose, tqdm_kwds)
#    1102     embedding = noisy_scale_coords(
#    1103         embedding, random_state, max_coord=10, noise=0.0001
#    1104     )
#    1105 elif isinstance(init, str) and init == "spectral":
# -> 1106     embedding = spectral_layout(
#    1107         data,
#    1108         graph,
#    1109         n_components,
#    1110         random_state,
#    1111         metric=metric,
#    1112         metric_kwds=metric_kwds,
#    1113     )
#    1114     # We add a little noise to avoid local minima for optimization to come
#    1115     embedding = noisy_scale_coords(
#    1116         embedding, random_state, max_coord=10, noise=0.0001
#    1117     )
#
# File ~\.env\nlp-project\Lib\site-packages\umap\spectral.py:304, in spectral_layout(data, graph, dim, random_state, metric, metric_kwds, tol, maxiter)
#     263 def spectral_layout(
#     264     data,
#     265     graph,
#    (...)
#     271     maxiter=0
#     272 ):
#     273     """
#     274     Given a graph compute the spectral embedding of the graph. This is
#     275     simply the eigenvectors of the laplacian of the graph. Here we use the
#    (...)
#     302         The spectral embedding of the graph.
#     303     """
# --> 304     return _spectral_layout(
#     305         data=data,
#     306         graph=graph,
#     307         dim=dim,
#     308         random_state=random_state,
#     309         metric=metric,
#     310         metric_kwds=metric_kwds,
#     311         init="random",
#     312         tol=tol,
#     313         maxiter=maxiter
#     314     )
#
# File ~\.env\nlp-project\Lib\site-packages\umap\spectral.py:467, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     464 n_components, labels = scipy.sparse.csgraph.connected_components(graph)
#     466 if n_components > 1:
# --> 467     return multi_component_layout(
#     468         data,
#     469         graph,
#     470         n_components,
#     471         labels,
#     472         dim,
#     473         random_state,
#     474         metric=metric,
#     475         metric_kwds=metric_kwds,
#     476     )
#     478 sqrt_deg = np.sqrt(np.asarray(graph.sum(axis=0)).squeeze())
#     479 # standard Laplacian
#     480 # D = scipy.sparse.spdiags(diag_data, 0, graph.shape[0], graph.shape[0])
#     481 # L = D - graph
#     482 # Normalized Laplacian
#
# File ~\.env\nlp-project\Lib\site-packages\umap\spectral.py:243, in multi_component_layout(data, graph, n_components, component_labels, dim, random_state, metric, metric_kwds, init, tol, maxiter)
#     234     result[component_labels == label] = (
#     235         random_state.uniform(
#     236             low=-data_range,
#    (...)
#     240         + meta_embedding[label]
#     241     )
#     242 else:
# --> 243     component_embedding = _spectral_layout(
#     244         data=None,
#     245         graph=component_graph,
#     246         dim=dim,
#     247         random_state=random_state,
#     248         metric=metric,
#     249         metric_kwds=metric_kwds,
#     250         init=init,
#     251         tol=tol,
#     252         maxiter=maxiter
#     253     )
#     254     expansion = data_range / np.max(np.abs(component_embedding))
#     255     component_embedding *= expansion
#
# File ~\.env\nlp-project\Lib\site-packages\umap\spectral.py:521, in _spectral_layout(data, graph, dim, random_state, metric, metric_kwds, init, method, tol, maxiter)
#     518 X[:, 0] = sqrt_deg / np.linalg.norm(sqrt_deg)
#     520 if method == "eigsh":
# --> 521     eigenvalues, eigenvectors = scipy.sparse.linalg.eigsh(
#     522         L,
#     523         k,
#     524         which="SM",
#     525         ncv=num_lanczos_vectors,
#     526         tol=tol or 1e-4,
#     527         v0=np.ones(L.shape[0]),
#     528         maxiter=maxiter or graph.shape[0] * 5,
#     529     )
#     530 elif method == "lobpcg":
#     531     with warnings.catch_warnings():
#
# File ~\.env\nlp-project\Lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:1700, in eigsh(A, k, M, sigma, which, v0, ncv, maxiter, tol, return_eigenvectors, Minv, OPinv, mode)
#    1698 with _ARPACK_LOCK:
#    1699     while not params.converged:
# -> 1700         params.iterate()
#    1702     return params.extract(return_eigenvectors)
#
# File ~\.env\nlp-project\Lib\site-packages\scipy\sparse\linalg\_eigen\arpack\arpack.py:537, in _SymmetricArpackParams.iterate(self)
#     535 def iterate(self):
#     536     self.ido, self.tol, self.resid, self.v, self.iparam, self.ipntr, self.info = \
# --> 537         self._arpack_solver(self.ido, self.bmat, self.which, self.k,
#     538                             self.tol, self.resid, self.v, self.iparam,
#     539                             self.ipntr, self.workd, self.workl, self.info)
#     541     xslice = slice(self.ipntr[0] - 1, self.ipntr[0] - 1 + self.n)
#     542     yslice = slice(self.ipntr[1] - 1, self.ipntr[1] - 1 + self.n)
#
# KeyboardInterrupt:
